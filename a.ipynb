# %%
# !python /teamspace/studios/this_studio/new_model/BranchDistillation/pretrained_sample_branch.py
# Out:
# Figure(640x480)

# %%
# !python /teamspace/studios/this_studio/new_model/ProgressiveDistillation/pretrained_sample.py
# Out:
# Figure(640x480)
