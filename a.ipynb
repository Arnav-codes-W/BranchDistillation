# %%
# !python fid_calculation.py

# %%
# !python /teamspace/studios/this_studio/new_model/pretrained_sample_branch.py
# Out:
# Figure(640x480)

# %%
# !python /teamspace/studios/this_studio/BranchDistillation/branchdistillation.py
# Out:
# ...
# Epoch 1/140:   3%|▏      | 13/391 [00:12<05:52,  1.07it/s, loss=4.8332, step=13]
# Traceback (most recent call last):
#   File "/teamspace/studios/this_studio/BranchDistillation/branchdistillation.py", line 199, in <module>
#     alpha_s, sigma_s = get_alpha_sigma(ddim_student, k, DEVICE)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/teamspace/studios/this_studio/BranchDistillation/branchdistillation.py", line 19, in get_alpha_sigma
#     alphas_cumprod = scheduler.alphas_cumprod.to(device)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
